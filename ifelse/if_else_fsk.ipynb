# %%
alter = 17

if alter >= 18:
    print("Film über 18 erlaubt")

elif alter >= 16:
    print("Film über 16 erlaubt")

elif alter >= 12:
    print("Film über 12 erlaubt")

elif alter >= 6:
    print("Film über 6 erlaubt")

else:
    print("TV aus")
# Out:
# Film über 16 erlaubt
