# %% [markdown]
# Einfache IF-Bedingung

# %%
a = 5
b = 10

if a < b:
    print("a ist kleiner b")

# %%
alter = 18
if alter >= 18:
    print("tanzen.....")

print("weiter..")

# %% [markdown]
# IF-Else

# %%
alter = 17

if alter >= 18:
    print("tanzen....")
else:
    print("ab nach hause...")
