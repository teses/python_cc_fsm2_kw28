# %%
def addiere(a, b):
    return a + b


# referenz auf die funktion
add = addiere

ergebnis = add(5, 3)
print(ergebnis)


# löscht man die referenz, wird nur die referenz gelöscht. NICHT das original
del add
ergebnis = add(5, 3)
print(ergebnis)
# Out:
# 8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 14
#      10
#      11
#      12 # löscht man die referenz, wird nur die referenz gelöscht. NICHT das original
#      13 del add
# ---> 14 ergebnis = add(5, 3)
#      15 print(ergebnis)
#      16
#      17
#
# NameError: name 'add' is not defined
