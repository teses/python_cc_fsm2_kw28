# %% [markdown]
# Eine Lambda-Funktion in Python ist eine kleine, **anonyme** Funktion, die du in einer **einzigen Zeile** definieren kannst.
# Sie wird oft für kurze Operationen verwendet, bei denen eine normale def-Funktion zu „umständlich“ wäre.
#
# Syntax
#
# `lambda argumente: ausdruck`
#
# - lambda → Schlüsselwort
# - argumente → Eingaben der Funktion (wie Parameter bei def)
# - ausdruck → genau ein Ausdruck, dessen Ergebnis zurückgegeben wird

# %%
def add_function(x, y):
    return x + y

# man kann die Funktion auch in einer Zeile schreiben
add = lambda x,y : x + y

print(add_function(3,5))
print(add(3,5))
# Out:
# 8

# %%
# Quadrieren
square = lambda n: n * n
print(square(4))  # Ausgabe: 16

# %%
# Mit bedingung
older18 = lambda x: x >= 18
print("older18", older18(17))
# Out:
# True
