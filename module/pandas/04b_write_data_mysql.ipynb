# %%
from sqlalchemy import create_engine
import pandas as pd

#
connection = create_engine(
    "mysql+pymysql://root:@localhost:3306/comcave_etl",
    echo=True
)


# Daten als JSON
daten = [
    {"Name": "Max", "Alter": 25, "Stadt": "Berlin"},
    {"Name": "Anna", "Alter": 30, "Stadt": "Hamburg"},
    {"Name": "Tom", "Alter": 22, "Stadt": "Köln"}
]
df = pd.DataFrame(daten)

count = df.to_sql(
    "personen",
    con=connection,
    if_exists="replace",  # replace , append
    index=False
)
print(f"importiert: {count}")
# Out:
# 2026-08-27 11:43:46,801 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-08-27 11:43:46,802 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-08-27 11:43:46,806 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-08-27 11:43:46,806 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-08-27 11:43:46,808 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-08-27 11:43:46,809 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-08-27 11:43:46,811 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-08-27 11:43:46,816 INFO sqlalchemy.engine.Engine DESCRIBE `comcave_etl`.`missing`
# 2026-08-27 11:43:46,817 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-08-27 11:43:46,841 INFO sqlalchemy.engine.Engine
# CREATE TABLE missing (
# 	id BIGINT,
# 	name TEXT,
# 	`alter` FLOAT(53),
# 	stadt TEXT,
# 	gehalt FLOAT(53),
# 	abteilung TEXT,
# 	eintrittsdatum TEXT
# )
#
#
# 2026-08-27 11:43:46,842 INFO sqlalchemy.engine.Engine [no key 0.00111s] {}
# 2026-08-27 11:43:46,946 INFO sqlalchemy.engine.Engine INSERT INTO missing (id, name, `alter`, stadt, gehalt, abteilung, eintrittsdatum) VALUES (%(id)s, %(name)s, %(alter)s, %(stadt)s, %(gehalt)s, %(abteilung)s, %(eintrittsdatum)s)
# 2026-08-27 11:43:46,947 INFO sqlalchemy.engine.Engine [generated in 0.00160s] [{'id': 1, 'name': 'Anna', 'alter': 29.0, 'stadt': 'Berlin', 'gehalt': 4200.0, 'abteilung': 'IT', 'eintrittsdatum': '2021-03-15'}, {'id': 2, 'name': 'Ben', 'alter': None, 'stadt': 'Hamburg', 'gehalt': 3900.0, 'abteilung': 'Vertrieb', 'eintrittsdatum': '2020-07-01'}, {'id': 3, 'name': 'Clara', 'alter': 35.0, 'stadt': None, 'gehalt': 5100.0, 'abteilung': 'IT', 'eintrittsdatum': '2019-11-20'}, {'id': 4, 'name': 'David', 'alter': 41.0, 'stadt': 'München', 'gehalt': None, 'abteilung': 'HR', 'eintrittsdatum': '2018-05-10'}, {'id': 5, 'name': 'Emma', 'alter': 27.0, 'stadt': 'Köln', 'gehalt': 4500.0, 'abteilung': None, 'eintrittsdatum': '2022-01-17'}, {'id': 6, 'name': 'Felix', 'alter': None, 'stadt': '-', 'gehalt': 4700.0, 'abteilung': 'Marketing', 'eintrittsdatum': '2021-09-30'}, {'id': 7, 'name': 'Greta', 'alter': 31.0, 'stadt': 'Düsseldorf', 'gehalt': None, 'abteilung': 'IT', 'eintrittsdatum': None}, {'id': 8, 'name': 'Hassan', 'alter': 45.0, 'stadt': 'Frankfurt', 'gehalt': 6200.0, 'abteilung': 'Management', 'eintrittsdatum': '2017-12-01'}  ... displaying 10 of 15 total bound parameter sets ...  {'id': 14, 'name': 'Noah', 'alter': 29.0, 'stadt': 'Hannover', 'gehalt': None, 'abteilung': 'Vertrieb', 'eintrittsdatum': '2020-10-19'}, {'id': 15, 'name': 'Olivia', 'alter': 37.0, 'stadt': 'Leipzig', 'gehalt': 5400.0, 'abteilung': 'Management', 'eintrittsdatum': None}]
# 2026-08-27 11:43:47,008 INFO sqlalchemy.engine.Engine COMMIT
# importiert: 15
