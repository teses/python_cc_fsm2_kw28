# %%
import pandas as pd

# Daten als JSON
daten = [
    {"Name": "Max", "Alter": 25, "Stadt": "Berlin"},
    {"Name": "Anna", "Alter": 30, "Stadt": "Hamburg"},
    {"Name": "Tom", "Alter": 22, "Stadt": "Köln"}
]

# Daten als DataFrame vorhanden
df = pd.DataFrame(daten)


df.to_csv("../../data/write_test.csv", index=False, sep=";", encoding="utf-8")
