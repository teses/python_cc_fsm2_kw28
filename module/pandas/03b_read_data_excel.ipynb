# %% [markdown]
# # Excel einlesen
#
# Alles funktioniert genauso wie bei CSV

# %% [markdown]
# # Auslesen der ersten Tabelle

# %%
import pandas as pd

file = "../../data/example.xlsx"
df = pd.read_excel(file)

#print(df)
print(df.to_string())
print(df.info())

# %% [markdown]
# # Auslesen einer bestimmten Tabelle

# %%
import pandas as pd

file = "../../data/example.xlsx"
df = pd.read_excel(file, sheet_name="Tabelle2")

print(df)
# print(df.to_string())
# print(df.head())
# print(df.info())
# print(df.dtypes)
# Out:
#      Produkt   Preis
# 0  RAM 32 GB  100.00
# 1  RAM 64 GB  999.99
