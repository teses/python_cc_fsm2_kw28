# %%
import pandas as pd

file = "../../data/sales_varianz.csv"
file = "../../data/missing_data.csv"
df = pd.read_csv(file)

# %% [markdown]
# # Erste Übersicht

# %%
#print(df)       #  alles anzeigen (nur die ersten und letzten Daten)
#print(df.to_string())       #  alles anzeigen
#print(df.head())       # erste 5 Zeilen
#print(df.tail())       # letzte 5 Zeilen
#print(df.shape) # (Zeilen, Spalten)
#print(df.columns)      # Spaltennamen
#print(df.info())       # Datentypen + fehlende Werte
print(df.dtypes)       # Datentypen

# %% [markdown]
# # Statistik

# %%
#print(df.describe())
print(df.describe(include='all'))
# Out:
#              Datum          Produkt   Kategorie        Preis        Menge  \
# count         1500             1500        1500  1500.000000  1500.000000
# unique         359               26           5          NaN          NaN
# top     2025-08-08  Schraubenzieher  Elektronik          NaN          NaN
# freq            10               71         457          NaN          NaN
# mean           NaN              NaN         NaN   210.680667    10.716667
# std            NaN              NaN         NaN   290.775531     5.840473
# min            NaN              NaN         NaN     1.500000     1.000000
# 25%            NaN              NaN         NaN    20.000000     6.000000
# 50%            NaN              NaN         NaN   100.000000    11.000000
# 75%            NaN              NaN         NaN   250.000000    16.000000
# max            NaN              NaN         NaN  1200.000000    20.000000
#
#        Region
# count    1500
# unique      4
# top       Ost
# freq      391
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %% [markdown]
# # Fehlende Werte

# %%
#print(df.isnull().sum())
print(df.isnull().mean() * 100)
# Out:
# id                 0.000000
# name               0.000000
# alter             26.666667
# stadt              6.666667
# gehalt            26.666667
# abteilung         13.333333
# eintrittsdatum    20.000000
# dtype: float64
