# %%
import sqlite3
import pandas as pd

connection = sqlite3.connect("../../data/todo.db")

df = pd.read_sql("SELECT * FROM todos", connection)


print(df)
print(df.info())
# Out:
#    todo_id todo_title todo_description                   todo_created_at
# 0        1         aa               bb               2026-08-24 12:04:10
# 1        2      Hallo             dddd               2026-08-24 12:04:22
# 2        3   Was geht             dddd               2026-08-24 12:04:39
# 3        4     Python      Lorem ipsum  2026-08-25T08:15:26.321271+00:00
# 4        5     Python      Lorem ipsum  2026-08-25T08:17:42.963682+00:00
# 5        6     Python      Lorem ipsum  2026-08-25T08:17:59.305510+00:00
# 6        7     Python      Lorem ipsum  2026-08-25T08:18:06.657496+00:00
# 7        8     Python      Lorem ipsum  2026-08-25T08:18:34.552263+00:00
# 8        9      ssfsf           sfsfsf  2026-08-25T09:22:51.663524+00:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   todo_id           9 non-null      int64
# ...
