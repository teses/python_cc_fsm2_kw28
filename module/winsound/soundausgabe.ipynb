# %% [markdown]
# # Soundausgabe mit dem Modul winsound

# %%
import winsound

# spielt eine wav
#winsound.PlaySound("../data/applause.wav", winsound.SND_FILENAME)
winsound.PlaySound("nope.wav", winsound.SND_FILENAME)

#
winsound.Beep(261, 200)
winsound.Beep(293, 200)
winsound.Beep(329, 200)
winsound.Beep(349, 200)
winsound.Beep(391, 200)
winsound.Beep(440, 200)
winsound.Beep(493, 200)
winsound.Beep(523, 200)
