# %% [markdown]
# # Fehlerbehandlung

# %% [markdown]
# **Syntax Error**

# %%
Syntax Error
# Out:
#   Cell In[2], line 2
#     Syntax Error
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# **IndentationError**

# %%
def test():
print("test")
# Out:
#   Cell In[3], line 2
#     print("test")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# **NameError**

# %%
print(gibtesnicht)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(gibtesnicht)
#
# NameError: name 'gibtesnicht' is not defined
