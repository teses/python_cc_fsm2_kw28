# %%
table = [
    ["Susi", "Sauer", "Susistr. 1"],
    ["Max", "Mustermann", "Musterstr. 1"],
    [
        ["hallo"]
    ]
]

print(table[1][2])
print(table[1][1][3])
print(table[2][0][0])
# Out:
# Musterstr. 1
# t
# hallo
