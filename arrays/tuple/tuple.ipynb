# %% [markdown]
# # tuple
# - Array - Tuple
# - Tupel sind sortiert und nicht veränderbar.
# - duplikate sind erlaubt

# %%
# ein tuple mit mehreren Einträgen
meineListe = ("Apfel", "Banane", "Zitrone", "Birne", "Kiwi")
print(meineListe)
print(len(meineListe))
print(type(meineListe))
# Out:
# ('Apfel', 'Banane', 'Zitrone', 'Birne', 'Kiwi')
# 5
# <class 'tuple'>

# %%
# Wenn man ein tuple mit einem Eintrag haben möchte muss
# mann folgende Syntax nehmen
meineListe = ("Apfel", )
print(meineListe, type(meineListe))
# Out:
# ('Apfel',) <class 'tuple'>

# %% [markdown]
# # Zugriff

# %%
meineListe = ("Apfel", "Banane", "Zitrone", "Birne", "Kiwi")

# Zugriff auf Elemente
print(meineListe[1])
print(meineListe[0])

# Zugriff auf Elemente mit negativen index
print(meineListe[-2])

# Zugriff mit Range
print(meineListe[3:5])
print(meineListe[:5])
print(meineListe[3:])
print(meineListe[-4:-2])

start = 3
ende = 5
print(meineListe[start:ende])
# Out:
# Banane
# Apfel
# Birne
# ('Birne', 'Kiwi')
# ('Apfel', 'Banane', 'Zitrone', 'Birne', 'Kiwi')
# ('Birne', 'Kiwi')
# ('Banane', 'Zitrone')
# ('Birne', 'Kiwi')
