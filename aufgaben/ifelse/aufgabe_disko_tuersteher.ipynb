# %% [markdown]
# Eine Disko
# - Menschen bis 18 Jahre dürfen nur bis 00:00 in die Disko
# - VIP Gäste bekommen ein Sekt
# - Menschen mit einem gelben T-Shirt bekommen auch ein Sekt
# - Alle anderen kommen ganz normal rein
# - Menschen unter 18 dürfen kein Alkohol bekommen
# - man bekommt max. 1 Sekt
#
#
# Bitte eine Lösung mit IF-Else
#
# Von der Idee her sitzt vor der Tür ein Roboter der nur die Sensoren hat und nur ein Output als Laufband. 1 -2 Sätze.
#
# Die Eingabe soll durch feste Variablen erfolgen:
# - Erstmal die variablen spezifizieren bzw. festlegen
# - Eingangsparameter
#
# Die Ausgabe soll ein einfacher print sein
# - Der Text wird ausgegeben

# %% [markdown]
# # Lösung 1

# %%
alter = 17
ist_vip = False
tshirt_farbe = "gelb"

darf_reingehilfen = True
u18_hinweis = ""
sekt_empfang = ""

if alter < 18:
    u18_hinweis = " Du darfst aber nur bis 00:00 Uhr bleiben!"
else:
    u18_hinweis = ""

if alter >= 18 and (ist_vip or tshirt_farbe.lower() == "gelb"):
    sekt_empfang = " Hier ist dein Willkommens-Sekt!"
else:
    sekt_empfang = ""

ausgabe_text = (f"Willkommen in der Kinderschubse!{u18_hinweis}{sekt_empfang} Viel Spaß!")

print(ausgabe_text)
# Out:
# Willkommen in der Kinderschubse! Du darfst aber nur bis 00:00 Uhr bleiben! Viel Spaß!

# %%
# Eingangsparameter des Roboters
alter = 16
uhrzeit = 1
ist_vip = False
shirtfarbe = "gelb"

# Zuerst wird der Einlass geprüft.
if alter < 18 and uhrzeit >= 24:
    print("Kein Einlass: Personen unter 18 Jahren dürfen nach 00:00 Uhr nicht hinein.")
else:
    print("Einlass erlaubt.")

    # Alkohol darf nur an volljährige Personen ausgegeben werden.
    if alter >= 18 and (ist_vip or shirtfarbe.lower() == "gelb"):
        print("Der Gast erhält ein Glas Sekt.")
    elif alter < 18:
        print("Der Gast erhält keinen Alkohol.")
    else:
        print("Der Gast kommt ganz normal hinein und erhält keinen Sekt.")
# Out:
# Einlass erlaubt.
# Der Gast erhält keinen Alkohol.

# %% [markdown]
# # Lösung 3
#
# - Menschen bis 18 Jahre dürfen nur bis 00:00 in die Disko - E
# - VIP Gäste bekommen ein Sekt - S
# - Menschen mit einem gelben T-Shirt bekommen auch ein Sekt - S
# - Alle anderen kommen ganz normal rein E
# - Menschen unter 18 dürfen kein Alkohol bekommen S
# - man bekommt max. 1 Sekt S
#
#
# Eingaben (Was sind die Eingangsparameter?)
# - unter18 = True/False
# - gelbesShirt = True/False
# - isVip = True/False
# - vor0Uhr = True/False
#
# Ausgabe Einlass => unter18, vor0Uhr
#
# - komm rein
# - komm rein bis 12 Uhr
# - kommst hier nicht rein
#
# Ausgabe Sekt  => unter18, gelbesShirt, isVip
#
# - "Nimm dir ein Sekt"

# %%
gelbesShirt = False
unter18 = True
isVip = False
vor0Uhr = False

#
if not unter18:
    print("komm rein")
elif unter18 and vor0Uhr:
    print("komm rein bis 12 Uhr")
else:
    print("kommst hier nicht rein")

#
if (isVip or gelbesShirt) and not unter18:
    print("Nimm dir ein Sekt")
# Out:
# kommst hier nicht rein
