# %% [markdown]
# Passwort analysieren
#
# Prüfe, ob ein Passwort
#
# mindestens 8 Zeichen lang ist,
# mindestens einen Großbuchstaben enthält,
# mindestens einen Kleinbuchstaben enthält,
# mindestens eine Zahl enthält.

# %%
passwort = "MeinGeheimes&§123"

mindestens_8 = len(passwort) >= 8
grossbuchstabe = any(zeichen.isupper() for zeichen in passwort)
kleinbuchstabe = any(zeichen.islower() for zeichen in passwort)
zahl = any(zeichen.isdigit() for zeichen in passwort)

print(f"Mindestens 8 Zeichen: {mindestens_8}")
print(f"Großbuchstabe vorhanden: {grossbuchstabe}")
print(f"Kleinbuchstabe vorhanden: {kleinbuchstabe}")
print(f"Zahl vorhanden: {zahl}")

if mindestens_8 and grossbuchstabe and kleinbuchstabe and zahl:
    print("ok")
else:
    print("nicht ok")
# Out:
# Mindestens 8 Zeichen: True
# Großbuchstabe vorhanden: True
# Kleinbuchstabe vorhanden: True
# Zahl vorhanden: True
# ok

# %% [markdown]
# # Lösung 2

# %%
passwort = "Sjasij2342kdf"
#
def password_analysis(password):
    up_letter = False
    low_letter = False
    min_letter = False
    zahl_letter = False


    for zeichen in password:
        if zeichen.isupper():
            up_letter = True

        if zeichen.islower():
            low_letter = True

        if zeichen.isdigit():
            zahl_letter = True

    if len(password) >= 8:
        min_letter = True

    if up_letter and low_letter and min_letter and zahl_letter:
        print("Du hast alle Anforderungen erfüllt.")
        print("Status:")
        return True
    else:
        print("Du hast nicht alle Anforderungen erfüllt.")
        print("Status:")
        return False


print(password_analysis(passwort))
# Out:
# Du hast alle Anforderungen erfüllt.
# Status:
# True

# %% [markdown]
# # Lösung 3

# %%
passwort = "MeinGeheimes&§123"

hat_grossbuchstaben = False
hat_kleinbuchstaben = False
hat_zahl = False

for zeichen in passwort:
    if zeichen.isupper():
        hat_grossbuchstaben = True
    elif zeichen.islower():
        hat_kleinbuchstaben = True
    elif zeichen.isdigit():
        hat_zahl = True

lang_genug = len(passwort) >= 8

print("Mindestens 8 Zeichen:", lang_genug)
print("Großbuchstabe vorhanden:", hat_grossbuchstaben)
print("Kleinbuchstabe vorhanden:", hat_kleinbuchstaben)
print("Zahl vorhanden:", hat_zahl)

if lang_genug and hat_grossbuchstaben and hat_kleinbuchstaben and hat_zahl:
    print("Das Passwort erfüllt alle Regeln.")
else:
    print("Das Passwort erfüllt nicht alle Regeln.")
# Out:
# Mindestens 8 Zeichen: True
# Großbuchstabe vorhanden: True
# Kleinbuchstabe vorhanden: True
# Zahl vorhanden: True
# Das Passwort erfüllt alle Regeln.
