# %%
emails = [
    "test@meinefirma.de",  # ok
    "TEST@meinefirma.de",  # ok
    "test123@meinefirma.de",  # ok
    "v.nachname@meinefirma.de", # ok
    "v-nachname@meinefirma.de", # ok
    "v_nachname@meinefirma.de", # ok
    "nicht gut@meinefirma.de", # falsch
    "nicht @meinefirma.de",  # falsch
    "ok@meinefirma.de " , # falsch
    " ok@meinefirma.de " , # falsch
    "thomas:eses@meinefirma.de " , # falsch
    "name@meinefirmade" , # falsch
]

# %% [markdown]
# # Lösung 1

# %%
import re

for email in emails:
    ergebnis = re.findall(r"^[a-zA-Z0-9._-]+@meinefirma\.de$", email)  # muster 1

    if ergebnis:
        print(f"Erfüllt:       '{email}'")
    else:
        print(f"Nicht erfüllt: '{email}'")



# muster = r"^[a-zA-Z0-9._-]+@meinefirma\.de$
# ^ = ab hier beginnt der text
# a-z = kleinbuchstabe
# A-Z = GROß
# 0-9 = zahlen
# ._- = zulässige sonderzeichen
# + = rechts muss was folgen
# meinefirma = muss genauso da stehen
# \. = punkt
# de = muss genauso da stehen
# $ = hier endet der Text
# Out:
# Erfüllt:       'test@meinefirma.de'
# Erfüllt:       'TEST@meinefirma.de'
# Erfüllt:       'test123@meinefirma.de'
# Erfüllt:       'v.nachname@meinefirma.de'
# Erfüllt:       'v-nachname@meinefirma.de'
# Erfüllt:       'v_nachname@meinefirma.de'
# Nicht erfüllt: 'nicht gut@meinefirma.de'
# Nicht erfüllt: 'nicht @meinefirma.de'
# Nicht erfüllt: 'ok@meinefirma.de '
# Nicht erfüllt: ' ok@meinefirma.de '
# Nicht erfüllt: 'thomas:eses@meinefirma.de '
# Erfüllt:       'name@meinefirmade'

# %% [markdown]
# # Lösung 2

# %%
for email in emails :
    ergebnis = re.search(r"^[\w.-]+@meinefirma.de$", email)
    print(f"{email} : {"true" if ergebnis else "false"}")
# Out:
# test@meinefirma.de : true
# TEST@meinefirma.de : true
# test123@meinefirma.de : true
# v.nachname@meinefirma.de : true
# v-nachname@meinefirma.de : true
# v_nachname@meinefirma.de : true
# nicht gut@meinefirma.de : false
# nicht @meinefirma.de : false
# ok@meinefirma.de  : false
#  ok@meinefirma.de  : false
# thomas:eses@meinefirma.de  : false
# name@meinefirmade : false
