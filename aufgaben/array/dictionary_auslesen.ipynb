# %%
product = {
  "product": {
    "id": "e9d10e5c6a1e4b3e944fb8fcde5bb883",
    "parentId": None,
    "name": "Premium Leather Jacket",
    "description": "A classic, genuine leather jacket with premium stitching.",
    "productNumber": "SW10001",
    "stock": 45,
    "availableStock": 45,
    "active": True,
    "shippingFree": False,
    "calculatedPrice": {
      "unitPrice": 199.99,
      "quantity": 1,
      "totalPrice": 199.99,
      "calculatedTaxes": [
        {
          "tax": 31.94,
          "taxRate": 19.0,
          "price": 199.99
        }
      ],
      "regulationPrice": None
    },
    "cover": {
      "id": "7a8b9c0d1e2f3g4h5i6j7k8l9m0n1o2p",
      "media": {
        "id": "media_id_12345",
        "url": "https://yourshopdomain.com",
        "alt": "Premium Leather Jacket front view",
        "width": 1200,
        "height": 1200
      }
    },
    "properties": [
      {
        "id": "prop_color_id",
        "name": "Color",
        "group": {
          "id": "group_color_id",
          "name": "Colors"
        },
        "translated": {
          "name": "Black"
        }
      },
      {
        "id": "prop_size_id",
        "name": "Size",
        "group": {
          "id": "group_size_id",
          "name": "Sizes"
        },
        "translated": {
          "name": "L"
        }
      }
    ],
    "manufacturer": {
      "id": "manufacturer_id_100",
      "name": "FashionBrand",
      "link": "https://yourshopdomain.com"
    }
  }
}

# %%
p_data = product["product"]

p_name = p_data["name"]
p_id = p_data["id"]

# Preis & Steuer
first_tax = p_data["calculatedPrice"]["calculatedTaxes"][0]
p_price = first_tax["price"]
p_tax_rate = first_tax["taxRate"]

# Eigenschaften zusammenbauen
properties_list = [
    f"{prop['name']} = {prop['translated']['name']}"
    for prop in p_data["properties"]
]

p_properties = ", ".join(properties_list)

p_manufacturer = p_data["manufacturer"]["name"]


print(f"Produkt Name: {p_name}")
print(f"Produkt ID: {p_id}")
print(f"Produkt Price: {p_price} €")
print(f"Produkt Tax Rate: {int(p_tax_rate)}%")
print(f"Eigenschaften: {p_properties}")
print(f"Hersteller Name: {p_manufacturer}")
# Out:
# Produkt Name: Premium Leather Jacket
# Produkt ID: e9d10e5c6a1e4b3e944fb8fcde5bb883
# Produkt Price: 199.99 €
# Produkt Tax Rate: 19%
# Eigenschaften: Color = Black, Size = L
# Hersteller Name: FashionBrand

# %% [markdown]
# - Produkt Name
# - Produkt ID
# - Produkt price  <-  calculatedTax => price
# - Produkt Tax Rate: 19%
# - Die Eigenschaften des Produktes : Color = Black, Size = L
# - Hersteller Name: FashionBrand
