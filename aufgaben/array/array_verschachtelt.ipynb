# %% [markdown]
# - Schreibe ein verschachteltes array - Eine Art CD Liste mit Tracks
# - Überlege welche Arten von Arrays Sinn machen.
# - Tipp: Denke an das JSON Format !!
#
# so ca. 2-3 Cds mit 2-3 Titeln
#
# https://www.discogs.com/master/8517-Michael-Jackson-Bad
#
# https://www.discogs.com/de/master/326803-Various-Bravo-Hits

# %%
cd_liste = "???"
